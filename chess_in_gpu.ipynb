# %% [markdown]
# <a href="https://colab.research.google.com/github/zinouzl/CH-Leach/blob/master/chess_in_gpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import chess
import chess.pgn
import tensorflow as tf
import os

# %%
with tf.Session() as sess:
    print(tf.test.is_gpu_available())
    devices = sess.list_devices()
for i in devices:
  print(i)
# Out:
# True
# _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456, 7403753625657960704)
# _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 17988688622440529455)
# _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_GPU:0, XLA_GPU, 17179869184, 11169785342285620579)
# _DeviceAttributes(/job:localhost/replica:0/task:0/device:GPU:0, GPU, 14800692839, 15304874887931122018)

# %%
p = chess.Board()
print(p)
print(*p.legal_moves)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# g1h3 g1f3 b1c3 b1a3 h2h3 g2g3 f2f3 e2e3 d2d3 c2c3 b2b3 a2a3 h2h4 g2g4 f2f4 e2e4 d2d4 c2c4 b2b4 a2a4

# %%
p.push_san('e4')
print(p)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R

# %%
import torch.nn as nn
import torch.nn.functional as F


class NetModel(nn.Module):
  def __init__(self):
    super(NetModel,self).__init__()
    self.conv1 = nn.Conv2d(1,20,kernel_size=3,padding=1)
    self.conv2 = nn.Conv2d(20,40,kernel_size=3,padding=1)
    self.conv3 = nn.Conv2d(40,60,kernel_size=3,padding=1)
    self.dropout1 = nn.Dropout2d()
    
    self.conv4 = nn.Conv2d(60,60,kernel_size=3,padding=1)
    self.conv5 = nn.Conv2d(60,60,kernel_size=3,padding=1)
    self.conv6 = nn.Conv2d(60,60,kernel_size=3,padding=1)
    self.dropout2 = nn.Dropout2d()
    
    self.linear1 = nn.Linear(60*8*8,512)
    self.linear2 = nn.Linear(512,1)
    self.linear3 = nn.Linear(6400,1)
    self.tanh = nn.Tanh()
    
  def forward(self,x):

    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = F.relu(self.conv3(x),2)
    x = self.dropout1(x)
    

    x = F.relu(self.conv4(x))
    x = F.relu(self.conv5(x))
    x = F.relu(self.conv6(x))
    self.dropout2(x)
    #print('before reshaping',x.shape)
    x = x.view(-1,8*8*60)
    #print('after reshaping',x.shape)
    x = F.relu(self.linear1(x))
    x = F.relu(self.linear2(x))
    #print(x.shape)
    
    return self.tanh(x)

# %%
from torch.utils.data import Dataset,DataLoader
from torchvision import transforms
import torch


class chessData(Dataset):
  def __init__(self,X,Y):
    self.X=torch.from_numpy(X)
    self.Y=torch.from_numpy(Y)
    self.length = Y.shape[0]
  def __getitem__(self,index):
    return self.X[index],self.Y[index]
  
  def __len__(self):
    return self.length

# %%
import chess
import numpy as np
class State:
  def __init__(self,board=None):
    if board ==None:
      self.board = chess.Board()
    else:
      self.board = board
  def serialize(self):
    assert self.board.is_valid()
    state = np.zeros((8,8,5))
    bstate = np.zeros((64),np.uint8)
    for i in range(8*8):
      pi = self.board.piece_at(i)
      if pi is not None:

        bstate[i] = {'P':1,'N':2,'B':3,'R':4,'Q':5,'K':6,\
                     'p':9,'n':10,'b':11,'r':12,'q':13,'k':14}[pi.symbol()]
    if self.board.has_legal_en_passant():
      assert bstate[self.board.ep_square] == 0
      bstate[self.board.ep_square] =8
    if self.board.has_queenside_castling_rights(True):
      assert bstate[0]==4
      bstate[0]=7
    if self.board.has_kingside_castling_rights(True):
      assert bstate[7]==4
      bstate[7]=7
    if self.board.has_queenside_castling_rights(False):
      assert bstate[64-8]==12
      bstate[56]=8+7
    if self.board.has_kingside_castling_rights(False):
      assert bstate[63]==8+4
      bstate[63]=8+7
     

    bstate=np.reshape(bstate,(8,8))
        
    state[:,:,4]=(self.board.turn*1.0)
    state[:,:,0]=(bstate>>1)&1
    state[:,:,1]=(bstate>>2)&1
    state[:,:,2]=(bstate>>3)&1
    state[:,:,3]=(bstate>>4)&1
    return np.swapaxes(np.transpose(state),1,2)
  def value(self):
    return 0

# %%
for i in os.listdir('./data'):
    #print(i)
    try:
        f = open(os.path.join("./data",i))
        
    except Exeption:
        print("whether the file do not exists or there is a problem with png function !")
        break
    game = 1
    while game!= None:
        game = chess.pgn.read_game(f)

        who_wins = game.headers['Result'] 
        print(who_wins)
        board = first_game.board()
        for i,move in enumerate(first_game.mainline_moves()):
        
            board.push(move)
            #print(' '*25+str(i),who_wins)
            #print(board)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-a2209702d19c> in <module>()
# ----> 1 for i in os.listdir('./data'):
#       2     #print(i)
#       3     try:
#       4         f = open(os.path.join("./data",i))
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: './data'

# %%
try:
  # !mkdir data
except Exception:
  print('file already exists')
#
#
# !wget http://kingbase-chess.net/download/747
# !ls
# Out:
# --2019-04-23 00:33:06--  http://kingbase-chess.net/download/747
# Resolving kingbase-chess.net (kingbase-chess.net)... 104.24.120.246, 104.24.121.246, 2606:4700:30::6818:78f6, ...
# Connecting to kingbase-chess.net (kingbase-chess.net)|104.24.120.246|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 458606123 (437M) [application/zip]
# Saving to: ‘747’
#
# 747                 100%[===================>] 437.36M  11.4MB/s    in 30s
#
# 2019-04-23 00:33:37 (14.5 MB/s) - ‘747’ saved [458606123/458606123]
#
# 747  data  sample_data

# %%
# Out:
# UnZip 6.00 of 20 April 2009, by Debian. Original by Info-ZIP.
#
# Usage: unzip [-Z] [-opts[modifiers]] file[.zip] [list] [-x xlist] [-d exdir]
#   Default action is to extract files in list, except those in xlist, to exdir;
#   file[.zip] may be a wildcard.  -Z => ZipInfo mode ("unzip -Z" for usage).
#
#   -p  extract files to pipe, no messages     -l  list files (short format)
#   -f  freshen existing files, create none    -t  test compressed archive data
#   -u  update files, create if necessary      -z  display archive comment only
#   -v  list verbosely/show version info       -T  timestamp archive to latest
#   -x  exclude files that follow (in xlist)   -d  extract files into exdir
# modifiers:
#   -n  never overwrite existing files         -q  quiet mode (-qq => quieter)
#   -o  overwrite files WITHOUT prompting      -a  auto-convert any text files
#   -j  junk paths (do not make directories)   -aa treat ALL files as text
#   -U  use escapes for all non-ASCII Unicode  -UU ignore any Unicode fields
#   -C  match filenames case-insensitively     -L  make (some) names lowercase
#   -X  restore UID/GID info                   -V  retain VMS version numbers
#   -K  keep setuid/setgid/tacky permissions   -M  pipe through "more" pager
#   -O CHARSET  specify a character encoding for DOS, Windows and OS/2 archives
#   -I CHARSET  specify a character encoding for UNIX and other archives
#
# See "unzip -hh" or unzip.txt for more help.  Examples:
#   unzip data1 -x joe   => extract all files except joe from zipfile data1.zip
#   unzip -p foo | more  => send contents of foo.zip via pipe into program more
#   unzip -fo foo ReadMe => quietly replace existing ReadMe if archive file newer

# %%
#!mv 747 ./data
# !ls
#!cd ./data
# !ls
#!mkdir data

# !unzip ./747 -d ./data/
# Out:
# 747  data  sample_data
# 747  data  sample_data
# Archive:  ./747
#   inflating: ./data/KingBase2019-A00-A39.pgn
#   inflating: ./data/KingBase2019-A40-A79.pgn
#   inflating: ./data/KingBase2019-A80-A99.pgn
#   inflating: ./data/KingBase2019-B00-B19.pgn
#   inflating: ./data/KingBase2019-B20-B49.pgn
#   inflating: ./data/KingBase2019-B50-B99.pgn
#   inflating: ./data/KingBase2019-C00-C19.pgn
#   inflating: ./data/KingBase2019-C20-C59.pgn
#   inflating: ./data/KingBase2019-C60-C99.pgn
#   inflating: ./data/KingBase2019-D00-D29.pgn
#   inflating: ./data/KingBase2019-D30-D69.pgn
#   inflating: ./data/KingBase2019-D70-D99.pgn
#   inflating: ./data/KingBase2019-E00-E19.pgn
#   inflating: ./data/KingBase2019-E20-E59.pgn
#   inflating: ./data/KingBase2019-E60-E99.pgn

# %%
#!mv ./data/747 ./
#!sudo apt-get install gdb

# %%
# this step is not neccesery but we use it to move files to data folder 
for i in os.listdir():
  if i[0]=='K':
    os.rename('./'+i,'./data/'+i)
  print(i[0])
# Out:
# .
# K
# K
# K
# K
# K
# d
# K
# K
# K
# K
# K
# K
# K
# K
# K
# K
# s

# %%
# !nvidia-smi
#!cat /proc/cpuinfo
import torch

print(torch.cuda.is_available())
# Out:
# Wed Mar 27 02:44:45 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.43       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    71W / 149W |    121MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# True

# %%
import optim

# %%
def get_dataset(data_size=10000):
  X=[]
  Y=[]
  for file in os.listdir('./data'):
      #print(i)
      try:
          f = open(os.path.join("./data",file))

      except Exception:
          print("whether the file does not exist or there is a problem with png function !")
          break
      game = 1
      game_number =0
      while game!= None:
          try:
            game = chess.pgn.read_game(f)
            game_number+=1
          except Exception:
            break

          who_wins = {'0-1':-1,'1-0':1,'1/2-1/2':0}[game.headers['Result']]
          print('parsing game #',game_number,' number of exemple parsed',len(X))
          state = State(game.board())
          for i,move in enumerate(game.main_line()):
              
              state.board.push(move)
              X.append(state.serialize()[0,:,:])
              Y.append(who_wins)
              #print(' '*25+str(i),who_wins)
              #print(board)
              if len(X)>data_size:
                return X,Y
            
      return X,Y
   
              
              
              
              
          
torch.set_default_tensor_type('torch.DoubleTensor')
X,Y = get_dataset()
X = np.reshape(np.array(X,dtype=float),(-1,1,8,8))
Y = np.array(Y)

datachess = chessData(X,Y)
model = NetModel()
Batch = DataLoader(dataset=datachess,batch_size=100)

def train_net(model,batch,criterion,optimizer)
for _ in range(1):
  for x,y in Batch:

    #print(x.shape)
    yhat = model(x)
    print(yhat)
# Out:
# parsing game # 1  nember of exemple parsed 0
# parsing game # 2  nember of exemple parsed 82
# parsing game # 3  nember of exemple parsed 186
# parsing game # 4  nember of exemple parsed 300
# parsing game # 5  nember of exemple parsed 375
# parsing game # 6  nember of exemple parsed 487
# parsing game # 7  nember of exemple parsed 611
# parsing game # 8  nember of exemple parsed 687
# parsing game # 9  nember of exemple parsed 790
# parsing game # 10  nember of exemple parsed 908
# parsing game # 11  nember of exemple parsed 982
# parsing game # 12  nember of exemple parsed 1072
# parsing game # 13  nember of exemple parsed 1155
# parsing game # 14  nember of exemple parsed 1379
# parsing game # 15  nember of exemple parsed 1481
# parsing game # 16  nember of exemple parsed 1546
# parsing game # 17  nember of exemple parsed 1636
# parsing game # 18  nember of exemple parsed 1742
# parsing game # 19  nember of exemple parsed 1853
# parsing game # 20  nember of exemple parsed 1913
# parsing game # 21  nember of exemple parsed 1965
# parsing game # 22  nember of exemple parsed 2023
# parsing game # 23  nember of exemple parsed 2232
# parsing game # 24  nember of exemple parsed 2285
# parsing game # 25  nember of exemple parsed 2398
# parsing game # 26  nember of exemple parsed 2444
# parsing game # 27  nember of exemple parsed 2541
# parsing game # 28  nember of exemple parsed 2699
# parsing game # 29  nember of exemple parsed 2784
# parsing game # 30  nember of exemple parsed 2916
# parsing game # 31  nember of exemple parsed 3033
# parsing game # 32  nember of exemple parsed 3202
# parsing game # 33  nember of exemple parsed 3336
# parsing game # 34  nember of exemple parsed 3440
# parsing game # 35  nember of exemple parsed 3503
# parsing game # 36  nember of exemple parsed 3598
# parsing game # 37  nember of exemple parsed 3651
# parsing game # 38  nember of exemple parsed 3719
# parsing game # 39  nember of exemple parsed 3800
# parsing game # 40  nember of exemple parsed 3868
# parsing game # 41  nember of exemple parsed 3961
# parsing game # 42  nember of exemple parsed 3995
# parsing game # 43  nember of exemple parsed 4066
# parsing game # 44  nember of exemple parsed 4163
# parsing game # 45  nember of exemple parsed 4270
# parsing game # 46  nember of exemple parsed 4360
# parsing game # 47  nember of exemple parsed 4456
# parsing game # 48  nember of exemple parsed 4550
# parsing game # 49  nember of exemple parsed 4703
# parsing game # 50  nember of exemple parsed 4858
# parsing game # 51  nember of exemple parsed 4935
# parsing game # 52  nember of exemple parsed 5045
# parsing game # 53  nember of exemple parsed 5102
# parsing game # 54  nember of exemple parsed 5202
# parsing game # 55  nember of exemple parsed 5245
# parsing game # 56  nember of exemple parsed 5398
# parsing game # 57  nember of exemple parsed 5496
# parsing game # 58  nember of exemple parsed 5594
# parsing game # 59  nember of exemple parsed 5707
# parsing game # 60  nember of exemple parsed 5801
# parsing game # 61  nember of exemple parsed 5891
# parsing game # 62  nember of exemple parsed 5954
# parsing game # 63  nember of exemple parsed 6055
# parsing game # 64  nember of exemple parsed 6128
# parsing game # 65  nember of exemple parsed 6193
# parsing game # 66  nember of exemple parsed 6300
# parsing game # 67  nember of exemple parsed 6380
# parsing game # 68  nember of exemple parsed 6449
# parsing game # 69  nember of exemple parsed 6534
# parsing game # 70  nember of exemple parsed 6577
# parsing game # 71  nember of exemple parsed 6611
# parsing game # 72  nember of exemple parsed 6692
# parsing game # 73  nember of exemple parsed 6861
# parsing game # 74  nember of exemple parsed 6960
# parsing game # 75  nember of exemple parsed 7018
# parsing game # 76  nember of exemple parsed 7074
# parsing game # 77  nember of exemple parsed 7232
# parsing game # 78  nember of exemple parsed 7373
# parsing game # 79  nember of exemple parsed 7421
# parsing game # 80  nember of exemple parsed 7468
# parsing game # 81  nember of exemple parsed 7557
# parsing game # 82  nember of exemple parsed 7646
# parsing game # 83  nember of exemple parsed 7717
# parsing game # 84  nember of exemple parsed 7768
# parsing game # 85  nember of exemple parsed 7851
# parsing game # 86  nember of exemple parsed 7983
# parsing game # 87  nember of exemple parsed 8064
# parsing game # 88  nember of exemple parsed 8179
# parsing game # 89  nember of exemple parsed 8296
# parsing game # 90  nember of exemple parsed 8374
# parsing game # 91  nember of exemple parsed 8420
# parsing game # 92  nember of exemple parsed 8589
# parsing game # 93  nember of exemple parsed 8717
# parsing game # 94  nember of exemple parsed 8798
# parsing game # 95  nember of exemple parsed 8899
# parsing game # 96  nember of exemple parsed 8939
# parsing game # 97  nember of exemple parsed 8986
# parsing game # 98  nember of exemple parsed 9056
# parsing game # 99  nember of exemple parsed 9201
# parsing game # 100  nember of exemple parsed 9226
# parsing game # 101  nember of exemple parsed 9323
# parsing game # 102  nember of exemple parsed 9386
# parsing game # 103  nember of exemple parsed 9485
# parsing game # 104  nember of exemple parsed 9543
# parsing game # 105  nember of exemple parsed 9628
# parsing game # 106  nember of exemple parsed 9720
# parsing game # 107  nember of exemple parsed 9790
# parsing game # 108  nember of exemple parsed 9912
# tensor([[0.0116],
#         [0.0113],
#         [0.0112],
#         [0.0115],
#         [0.0116],
#         [0.0117],
#         [0.0113],
#         [0.0117],
#         [0.0109],
#         [0.0115],
#         [0.0114],
#         [0.0118],
#         [0.0115],
#         [0.0115],
#         [0.0118],
#         [0.0109],
#         [0.0113],
#         [0.0111],
#         [0.0121],
#         [0.0111],
#         [0.0109],
#         [0.0111],
#         [0.0108],
#         [0.0109],
#         [0.0114],
#         [0.0114],
#         [0.0112],
#         [0.0110],
#         [0.0114],
#         [0.0115],
#         [0.0116],
#         [0.0111],
#         [0.0114],
#         [0.0110],
#         [0.0111],
#         [0.0112],
#         [0.0114],
#         [0.0109],
#         [0.0116],
#         [0.0112],
#         [0.0108],
#         [0.0109],
#         [0.0118],
#         [0.0113],
#         [0.0117],
#         [0.0116],
#         [0.0114],
#         [0.0110],
#         [0.0111],
#         [0.0115],
#         [0.0111],
#         [0.0114],
#         [0.0111],
#         [0.0118],
#         [0.0114],
#         [0.0113],
#         [0.0118],
#         [0.0115],
#         [0.0116],
#         [0.0114],
#         [0.0112],
#         [0.0111],
#         [0.0121],
#         [0.0111],
#         [0.0120],
#         [0.0123],
#         [0.0119],
#         [0.0111],
#         [0.0113],
#         [0.0113],
#         [0.0117],
#         [0.0117],
#         [0.0115],
#         [0.0114],
#         [0.0117],
#         [0.0117],
#         [0.0113],
#         [0.0111],
#         [0.0116],
#         [0.0112],
#         [0.0113],
#         [0.0116],
#         [0.0116],
#         [0.0116],
#         [0.0116],
#         [0.0113],
#         [0.0112],
#         [0.0111],
#         [0.0117],
#         [0.0111],
#         [0.0110],
#         [0.0115],
#         [0.0113],
#         [0.0117],
#         [0.0119],
#         [0.0116],
#         [0.0117],
#         [0.0111],
#         [0.0120],
#         [0.0115],
#         [0.0113],
#         [0.0109],
#         [0.0114],
#         [0.0118],
#         [0.0113],
#         [0.0116],
#         [0.0119],
#         [0.0116],
#         [0.0117],
#         [0.0113],
#         [0.0117],
#         [0.0115],
#         [0.0122],
#         [0.0112],
#         [0.0114],
#         [0.0118],
#         [0.0117],
#         [0.0113],
#         [0.0115],
#         [0.0113],
#         [0.0116],
#         [0.0113],
#         [0.0116],
#         [0.0112],
#         [0.0110],
#         [0.0113],
#         [0.0113]], grad_fn=<TanhBackward>)
# tensor([[0.0113],
#         [0.0109],
#         [0.0110],
#         [0.0110],
#         [0.0110],
#         [0.0113],
#         [0.0113],
#         [0.0111],
#         [0.0112],
#         [0.0110],
#         [0.0115],
#         [0.0113],
#         [0.0111],
#         [0.0116],
#         [0.0113],
#         [0.0115],
#         [0.0113],
#         [0.0114],
#         [0.0110],
#         [0.0110],
#         [0.0109],
#         [0.0115],
#         [0.0110],
#         [0.0115],
#         [0.0113],
#         [0.0117],
#         [0.0113],
#         [0.0113],
#         [0.0110],
#         [0.0115],
#         [0.0119],
#         [0.0116],
#         [0.0114],
#         [0.0113],
#         [0.0112],
#         [0.0113],
#         [0.0115],
#         [0.0115],
#         [0.0114],
#         [0.0114],
#         [0.0115],
#         [0.0113],
#         [0.0113],
#         [0.0114],
#         [0.0110],
#         [0.0111],
#         [0.0115],
#         [0.0115],
#         [0.0114],
#         [0.0110],
#         [0.0110],
#         [0.0111],
#         [0.0112],
#         [0.0111],
#         [0.0111],
#         [0.0109],
#         [0.0112],
#         [0.0110],
#         [0.0112],
#         [0.0113],
#         [0.0110],
#         [0.0107],
#         [0.0110],
#         [0.0113],
#         [0.0117],
#         [0.0116],
#         [0.0113],
#         [0.0112],
#         [0.0110],
#         [0.0112],
#         [0.0114],
#         [0.0111],
#         [0.0112],
#         [0.0116],
#         [0.0113],
#         [0.0118],
#         [0.0113],
#         [0.0115],
#         [0.0113],
#         [0.0118],
#         [0.0115],
#         [0.0114],
#         [0.0114],
#         [0.0112],
#         [0.0117],
#         [0.0115],
#         [0.0116],
#         [0.0115],
#         [0.0110],
#         [0.0113],
#         [0.0116],
#         [0.0116],
#         [0.0112],
#         [0.0112],
#         [0.0115],
#         [0.0115],
#         [0.0117],
#         [0.0116],
#         [0.0113],
#         [0.0112]], grad_fn=<TanhBackward>)
# tensor([[0.0118],
#         [0.0111],
#         [0.0113],
#         [0.0110],
#         [0.0113],
#         [0.0113],
#         [0.0112],
#         [0.0114],
#         [0.0113],
#         [0.0114],
#         [0.0115],
#         [0.0111],
#         [0.0112],
#         [0.0115],
#         [0.0115],
#         [0.0113],
#         [0.0113],
#         [0.0114],
#         [0.0115],
#         [0.0113],
#         [0.0113],
#         [0.0112],
#         [0.0113],
#         [0.0115],
#         [0.0118],
#         [0.0113],
#         [0.0117],
#         [0.0110],
#         [0.0114],
#         [0.0114],
#         [0.0117],
#         [0.0114],
#         [0.0111],
#         [0.0115],
#         [0.0115],
#         [0.0110],
#         [0.0112],
#         [0.0117],
#         [0.0114],
#         [0.0116],
#         [0.0113],
#         [0.0111],
#         [0.0120],
#         [0.0114],
#         [0.0117],
#         [0.0117],
#         [0.0114],
#         [0.0113],
#         [0.0116],
#         [0.0113],
#         [0.0115],
#         [0.0115],
#         [0.0109],
#         [0.0111],
#         [0.0112],
#         [0.0111],
#         [0.0111],
#         [0.0118],
#         [0.0117],
#         [0.0115],
#         [0.0115],
#         [0.0116],
#         [0.0115],
#         [0.0117],
#         [0.0112],
#         [0.0116],
#         [0.0114],
#         [0.0113],
#         [0.0109],
#         [0.0115],
#         [0.0115],
#         [0.0114],
#         [0.0114],
#         [0.0114],
#         [0.0112],
#         [0.0108],
#         [0.0111],
#         [0.0113],
#         [0.0113],
#         [0.0109]], grad_fn=<TanhBackward>)
# tensor([[0.0113],
#         [0.0111],
#         [0.0111],
#         [0.0117],
#         [0.0111],
#         [0.0117],
#         [0.0113],
#         [0.0113],
#         [0.0114],
#         [0.0116],
#         [0.0108],
#         [0.0111],
#         [0.0107],
#         [0.0113],
#         [0.0107],
#         [0.0109],
#         [0.0111],
#         [0.0114],
#         [0.0110],
#         [0.0113],
#         [0.0112],
#         [0.0111],
#         [0.0112],
#         [0.0116],
#         [0.0113],
#         [0.0110],
#         [0.0113],
#         [0.0110],
#         [0.0111],
#         [0.0111],
#         [0.0115],
#         [0.0113],
#         [0.0114],
#         [0.0116],
#         [0.0109],
#         [0.0114],
#         [0.0112],
#         [0.0114],
#         [0.0112],
#         [0.0113],
#         [0.0112],
#         [0.0113],
#         [0.0116],
#         [0.0116],
#         [0.0118],
#         [0.0115],
#         [0.0114],
#         [0.0112],
#         [0.0117],
#         [0.0114],
#         [0.0115],
#         [0.0114],
#         [0.0118],
#         [0.0112],
#         [0.0119],
#         [0.0113],
#         [0.0114],
#         [0.0110],
#         [0.0113],
#         [0.0114],
#         [0.0114],
#         [0.0117],
#         [0.0110],
#         [0.0117],
#         [0.0112],
#         [0.0112],
#         [0.0114],
#         [0.0113],
#         [0.0115],
#         [0.0116],
#         [0.0117],
#         [0.0116],
#         [0.0118],
#         [0.0114],
#         [0.0114],
#         [0.0113],
#         [0.0115],
#         [0.0114],
#         [0.0111],
#         [0.0114],
#         [0.0115],
#         [0.0114],
#         [0.0113],
#         [0.0111],
#         [0.0113],
#         [0.0113],
#         [0.0114],
#         [0.0116],
#         [0.0114],
#         [0.0113],
#         [0.0112],
#         [0.0112],
#         [0.0116],
#         [0.0115],
#         [0.0118],
#         [0.0122],
#         [0.0116],
#         [0.0115],
#         [0.0116],
#         [0.0111]], grad_fn=<TanhBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-3be5dd35771b> in <module>()
#      51
#      52     #print(x.shape)
# ---> 53     yhat = model(x)
#      54     print(yhat)
#      55
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-37-5ecef3435e15> in forward(self, x)
#      30
#      31     x = F.relu(self.conv4(x))
# ---> 32     x = F.relu(self.conv5(x))
#      33     x = F.relu(self.conv6(x))
#      34     self.dropout2(x)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# KeyboardInterrupt:

# %%
#!cat /proc/cpuinfo
import torch
print(torch.__version__)
# Out:
# 1.0.1.post2
